# %% [markdown]
# # Getting Started with GitHub Copilot 🚀
#
# <span style="color: orange;">⏲️ Time: 20 Mins</span>
#
# ---
#
# ## Introduction
#
# Welcome to the **GitHub Copilot Getting Started Lab**! In this lab, you'll learn how to use GitHub Copilot to supercharge your coding experience with AI-powered suggestions, code completions, and more. Let's have some fun and get productive!
#
# ---
#
# <div style="display: flex; align-items: center; border: 2px solid #222; border-radius: 12px; padding: 16px; background: #111; color: #fafafa;">
#   <img src="../../images/robo1.png" alt="Robo1" style="width: 120px; margin-right: 24px;">
#     <div style="font-size: 1em;">
#       🤖 "I'm Robo1, your Copilot buddy! I don't drink coffee, but I do run on pure code. </br>
#       Ready to code like your keyboard owes you money?"
#     </div>
# </div>

# %% [markdown]
# ## 🤖 What is an LLM (Large Language Model)?
#
# Imagine a super-smart robot that reads tons of books, articles, and code. An LLM is a machine learning model trained on massive text data to understand and generate human-like language. It can answer questions, write stories, and even code!
#
# ### LLM for Code
#
# LLMs for code are trained on programming languages, documentation, and open-source projects. They can write code, fix bugs, and explain concepts. Think of them as your AI coding buddy!
#
# ---
#
# ## 🧑‍💻 GitHub Copilot: The Interface on Top of LLM
#
# GitHub Copilot is like a friendly wizard sitting on top of an LLM. It listens to your requests and uses the LLM's magic to help you code faster and smarter.

# %% [markdown]
# <span style="color: orange; font-size: 1.5em;">Steps to Use GitHub Copilot</span>
#
# ### 1. Install GitHub Copilot Extension
# - Open VS Code.
# - Go to Extensions (`Ctrl+Shift+X`).
# - Search for **GitHub Copilot** and click **Install**.
#
# ### 2. Sign In to GitHub
# - After installation, sign in with your GitHub account.
# - Make sure you have a Copilot subscription or trial.
#
#
# ### 3. **Start Coding with GitHub Copilot!** 🚀
# - Open a file and start typing code.
# - Watch Copilot suggest code completions, snippets, and even entire functions!
# - Accept suggestions with `Tab` and see your productivity soar.
# - Celebrate your new AI-powered coding buddy! 🥳

# %% [markdown]
# ---
#
# ## Scenario- Walmart Ecommerce
#
# Suppose you are building a backend for Walmart's ecommerce platform.
#
# <span style="color: red; font-size: 1em;">⚠️ For this Lab, refer to <code>copilot/Labs/Lab1</code> folder</span>
#
#
# ### **🟢 Exercise 1: Generate Code for your Product**
#
# <span style="color: orange; font-size: 1em;">Step 1: Open <code>Product.java</code> Class</span> </br></br>
# <span style="color: orange; font-size: 1em;">Step 2: Enter Below Prompt</span>
#
# ```java
# // Represents a product in Walmart's ecommerce system
# ```
#
# > 💡 *Copilot will suggest you some code. Press Tab to accept the changes

# %% [markdown]
# <span style="color: orange; font-size: 1em;">Step 3: Modify Code</span>
#
# Select the generated code, click on the star icon, and choose **Modify**.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color: orange; font-size: 1em;">Step 4: Add Additional Field <code>category</code></span>
#
# Add below prompt in the modify tab
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color: orange; font-size: 1em;">Step 5: Accept the changes</span>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **🟢 Exercise 2: Walmart’s Discount System**
#
# Scenario:
# Walmart offers dynamic discounts for the products. The developers need to automate the discount calculation.

# %% [markdown]
# <span style="color: orange; font-size: 1em;">Step 1: Open <code>DiscountCalculator.java</code> Class</span> </br></br>
# <span style="color: orange; font-size: 1em;">Step 2: Enter Below Prompt</span>
#
# ```java
#  // Function to calculate Walmart's dynamic discounts
#  ```
# <span style="color: orange; font-size: 1em;">Step 3: Press tab to accept the changes</span>
#
# <span style="color: orange; font-size: 1em;">Step 4: Modify the function to apply an extra 5% discount on orders above $500.</span>

# %% [markdown]
# # 🚀 Modes in Copilot: Ask, Edit, Agent
#
# Here are the three main modes you can use:
#
# - **Ask Mode**: Just ask questions! Copilot will answer, explain, or guide you.
# - **Edit Mode**: Make changes to your code or files. Copilot helps you refactor, fix, or enhance your code.
# - **Agent Mode**: Copilot acts as your coding sidekick, automating tasks, running commands, and connecting tools.

# %% [markdown]
# ### **🟢 Exercise 3: Edit Mode**
#
# <span style="color: orange; font-size: 1em;">Step 1: Open the chat in Edit Mode</span> </br></br>
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <span style="color: orange; font-size: 1em;">Step 2: Enter Below Prompt</span>
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <span style="color: orange; font-size: 1em;">Step 3: Keep the changes</span>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
#
# <table><tr>
# <td><img src="../../images/robo2.png" alt="Robo2 the AI Cheerleader" width="120" style="float:right; margin-left:16px;" /></td>
# <td style="vertical-align:top; padding-left:16px;">
# **<b>🎉 Congrats, you absolute legend!</b>**<br>
# Your code is now officially cooler than your playlist.
# But don't ask me to debug your coffee machine, I don't do such pitty jobs, rather I do code and you fix your coffee machine now
