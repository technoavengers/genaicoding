# %% [markdown]
# # Working with MCP Tools

# %% [markdown]
# ## Introduction
#
# In this Lab, we will add the Google Map MCP tool into our GitHub Copilot environment.

# %% [markdown]
# <div style="background: #111; border-radius: 12px; border: 2px solid #333; padding: 20px; display: flex; align-items: center; gap: 24px;">
#     <img src="../../images/robo1.png" alt="Robo1" style="width: 120px; height: auto; border-radius: 8px;">
#     <div style="color: #fff;">
#         <strong>Robo1 says:</strong><br>
#         Ready to explore the world? With Google Map MCP, I can find the fastest route to your favorite pizza place, discover hidden gems, and never get lost—even if I take a wrong turn in cyberspace!
#     </div>
# </div>

# %% [markdown]
# <div style="background: #222; border-radius: 12px; border: 2px solid #444; padding: 20px; color: #fff; margin-top: 16px;">
#   <strong>Explore MCP Servers!</strong><br>
#   Visit <a href="https://github.com/modelcontextprotocol/servers?tab=readme-ov-file" target="_blank" style="color: #4fc3f7; text-decoration: underline;">this link</a> and explore all available MCP Server projects. Discover the variety of tools and integrations you can use in your own AI workflows!
# </div>

# %% [markdown]
# <div style="background: #222; border-radius: 12px; border: 2px solid #444; padding: 20px; color: #fff; margin-top: 16px;">
# From the list of MCP Servers, click on <a href="https://github.com/modelcontextprotocol/servers-archived/tree/main/src/google-maps" style="color:#4fc3f7; text-decoration: underline;">Google Map</a> and review all the APIs available. Explore the endpoints and features provided, and think about how you could use them in your own projects!
# </div>

# %% [markdown]
# On above page, scroll down and check the NPX package to install Google Map MCP Server

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 1: Add Google Map to your Copilot
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 1:</span> <span style="color:#1976d2;">Open chat in Agent Mode</span>
#
# Click on the tool icon in the chat window. </br>
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# </span> <span style="color:#1976d2;">Step 2: Click on ![image.png](attachment:image.png) to add new MCP Server</span>
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  </span> <span style="color:#1976d2;">Step 3: Enter the name of Google Map Package</span>
#
# @modelcontextprotocol/server-google-maps and  Press Enter
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  </span> <span style="color:#1976d2;">Step 4: Allow the Package</span>
#
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  </span> <span style="color:#1976d2;">Step 5: Enter Google Map API Key</span>
#
# Copy the API Key shared by instructor in chat
#
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <span style="color: red; font-weight: bold;">Disclaimer:</span> This is my Google Map API Key.
# For this execrise, you can continue using my API Key but ideally, you should obtain your own API key from <a href="https://console.cloud.google.com/google/maps-apis" style="color: red; text-decoration: underline;">this link</a>.

# %% [markdown]
#  </span> <span style="color:#1976d2;">Step 6: Finally Press enter to confirm</span>
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  </span> <span style="color:#1976d2;">Step 7: Choose Workspace to install it only in this workspace</span>
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  </span> <span style="color:#1976d2;">Step 8: Your Google Cloud MCP Server is added</span>
#
#  mcp.json file is added inside .vscode folder
#
#  <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  </span> <span style="color:#1976d2;">Step 9: Check your MCP Servers</span>
#
# Click on Extension in Vscode Tool Bar
#
#  <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color: orange;">You should be able to see google-maps under MCP Servers</span>

# %% [markdown]
# ## Exercise 1: Use Google Cloud MCP Server
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 1:</span> <span style="color:#1976d2;">Open chat in Agent Mode</span>
#
# #google-maps Search lotus boulevard, noida
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 2:</span> <span style="color:#1976d2;">Try some more </span>
#
# #google-maps Give me direction from lotus boulevard noida to spezia bistro sector-104

# %% [markdown]
# <div style="background: #111; border-radius: 12px; border: 2px solid #333; padding: 20px; display: flex; align-items: center; gap: 24px;">
#     <img src="../../images/robo1.png" alt="Robo1" style="width: 120px; height: auto; border-radius: 8px;">
#     <div style="color: #fff;">
#         <strong>Robo1 says:</strong><br>
#         <span style="font-size:120%; color:#4fc3f7;">🎉 Congratulations!</span><br>
#         You did it! The Google Map MCP tool is now part of your Copilot arsenal.<br>
#         Ready to teleport to pizza places, dodge traffic jams, and discover secret shortcuts? With me as your guide, the world is just a click away—no batteries required!
#     </div>
# </div>
